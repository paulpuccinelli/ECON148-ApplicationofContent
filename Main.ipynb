# %%
try:
    import yfinance as yf
except: 
    # %pip install yfinance
    import yfinance as yf 
# %pip install yfinance[nospam]
import requests_cache
try:
    from mplchart.chart import Chart
except: 
    # %pip install mplchart
    from mplchart.chart import Chart
import pandas as pd
# Out:
# Requirement already satisfied: yfinance[nospam] in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.2.54)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from yfinance[nospam]) (2.4.6)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from yfinance[nospam]) (0.0.11)
# Requirement already satisfied: requests>=2.31 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from yfinance[nospam]) (2.32.3)
# Requirement already satisfied: pytz>=2022.5 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from yfinance[nospam]) (2025.1)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from yfinance[nospam]) (4.3.6)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from yfinance[nospam]) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from yfinance[nospam]) (2.2.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from yfinance[nospam]) (4.13.3)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from yfinance[nospam]) (3.17.9)
# Collecting requests_cache>=1.0
#   Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#      ---------------------------------------- 0.0/61.4 kB ? eta -:--:--
#      ---------------------------------------- 61.4/61.4 kB 3.2 MB/s eta 0:00:00
# Collecting requests_ratelimiter>=0.3.1
#   Downloading requests_ratelimiter-0.7.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from beautifulsoup4>=4.11.1->yfinance[nospam]) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from beautifulsoup4>=4.11.1->yfinance[nospam]) (2.6)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=1.3.0->yfinance[nospam]) (2025.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=1.3.0->yfinance[nospam]) (2.9.0.post0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.31->yfinance[nospam]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.31->yfinance[nospam]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.31->yfinance[nospam]) (2025.1.31)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.31->yfinance[nospam]) (3.4.1)
# Collecting url-normalize>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Collecting attrs>=21.2
#   Downloading attrs-25.1.0-py3-none-any.whl (63 kB)
#      ---------------------------------------- 0.0/63.2 kB ? eta -:--:--
#      ---------------------------------------- 63.2/63.2 kB 3.3 MB/s eta 0:00:00
# Collecting cattrs>=22.2
#   Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
#      ---------------------------------------- 0.0/66.4 kB ? eta -:--:--
#      ---------------------------------------- 66.4/66.4 kB 3.7 MB/s eta 0:00:00
# Collecting pyrate-limiter<3.0
#   Downloading pyrate_limiter-2.10.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from cattrs>=22.2->requests_cache>=1.0->yfinance[nospam]) (1.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance[nospam]) (1.17.0)
# Installing collected packages: url-normalize, pyrate-limiter, attrs, requests_ratelimiter, cattrs, requests_cache
# Successfully installed attrs-25.1.0 cattrs-24.1.2 pyrate-limiter-2.10.0 requests_cache-1.2.1 requests_ratelimiter-0.7.0 url-normalize-1.4.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: C:\Users\sense\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Out:
# Collecting mplchart
#   Downloading mplchart-0.0.22-py3-none-any.whl (565 kB)
#      ---------------------------------------- 0.0/565.2 kB ? eta -:--:--
#      -------------------------------- ---- 491.5/565.2 kB 15.5 MB/s eta 0:00:01
#      -------------------------------------- 565.2/565.2 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from mplchart) (2.2.3)
# Collecting matplotlib
#   Downloading matplotlib-3.10.1-cp310-cp310-win_amd64.whl (8.1 MB)
#      ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#      -- ------------------------------------- 0.5/8.1 MB 15.2 MB/s eta 0:00:01
#      ----- ---------------------------------- 1.1/8.1 MB 13.7 MB/s eta 0:00:01
#      -------- ------------------------------- 1.6/8.1 MB 12.9 MB/s eta 0:00:01
#      ---------- ----------------------------- 2.2/8.1 MB 12.7 MB/s eta 0:00:01
#      ------------- -------------------------- 2.7/8.1 MB 12.4 MB/s eta 0:00:01
#      ---------------- ----------------------- 3.3/8.1 MB 12.2 MB/s eta 0:00:01
#      ------------------- -------------------- 3.8/8.1 MB 12.2 MB/s eta 0:00:01
#      --------------------- ------------------ 4.4/8.1 MB 12.2 MB/s eta 0:00:01
#      ------------------------ --------------- 4.9/8.1 MB 12.2 MB/s eta 0:00:01
#      --------------------------- ------------ 5.5/8.1 MB 12.1 MB/s eta 0:00:01
#      ------------------------------ --------- 6.0/8.1 MB 12.1 MB/s eta 0:00:01
#      -------------------------------- ------- 6.6/8.1 MB 12.1 MB/s eta 0:00:01
#      ----------------------------------- ---- 7.2/8.1 MB 12.1 MB/s eta 0:00:01
#      -------------------------------------- - 7.7/8.1 MB 12.0 MB/s eta 0:00:01
#      ---------------------------------------  8.0/8.1 MB 12.0 MB/s eta 0:00:01
#      ---------------------------------------- 8.1/8.1 MB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from mplchart) (2.2.3)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.56.0-cp310-cp310-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#      ----------- ---------------------------- 0.6/2.2 MB 12.9 MB/s eta 0:00:01
#      --------------------- ------------------ 1.2/2.2 MB 12.4 MB/s eta 0:00:01
#      ------------------------------- -------- 1.7/2.2 MB 12.3 MB/s eta 0:00:01
#      ---------------------------------------  2.2/2.2 MB 12.7 MB/s eta 0:00:01
#      ---------------------------------------- 2.2/2.2 MB 11.7 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->mplchart) (2.9.0.post0)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.1-cp310-cp310-win_amd64.whl (218 kB)
#      ---------------------------------------- 0.0/218.6 kB ? eta -:--:--
#      ------------------------------------- 218.6/218.6 kB 13.9 MB/s eta 0:00:00
# Collecting pillow>=8
#   Downloading pillow-11.1.0-cp310-cp310-win_amd64.whl (2.6 MB)
#      ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#      -------- ------------------------------- 0.6/2.6 MB 12.2 MB/s eta 0:00:01
#      ----------------- ---------------------- 1.1/2.6 MB 12.0 MB/s eta 0:00:01
#      ------------------------- -------------- 1.7/2.6 MB 11.9 MB/s eta 0:00:01
#      ---------------------------------- ----- 2.2/2.6 MB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 MB 12.0 MB/s eta 0:00:01
#      ---------------------------------------- 2.6/2.6 MB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->mplchart) (24.2)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
#      ---------------------------------------- 0.0/107.7 kB ? eta -:--:--
#      -------------------------------------- 107.7/107.7 kB 6.1 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.8-cp310-cp310-win_amd64.whl (71 kB)
#      ---------------------------------------- 0.0/71.9 kB ? eta -:--:--
#      ---------------------------------------- 71.9/71.9 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->mplchart) (2025.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->mplchart) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\sense\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib->mplchart) (1.17.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, mplchart
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.56.0 kiwisolver-1.4.8 matplotlib-3.10.1 mplchart-0.0.22 pillow-11.1.0 pyparsing-3.2.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: C:\Users\sense\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
session = requests_cache.CachedSession('yfinance.cache')
session.headers['User-agent'] = 'my-program/1.0'
ticker = yf.Ticker('MSFT', session=session)

# The scraped response will be stored in the cache
ticker.actions

# %%
#List of Stock Exchanges Globally - credit to ChatGPT o1
stock_exchanges = {
  "New York Stock Exchange (NYSE)": "Longitude: -74.0113, Latitude: 40.7069",
  "NASDAQ (MarketSite in Times Square)": "Longitude: -73.9855, Latitude: 40.7570",
  "London Stock Exchange (LSE)": "Longitude: -0.0983, Latitude: 51.5155",
  "Tokyo Stock Exchange (TSE)": "Longitude: 139.7748, Latitude: 35.6828",
  "Shanghai Stock Exchange (SSE)": "Longitude: 121.5010, Latitude: 31.2382",
  "Hong Kong Stock Exchange (HKEX)": "Longitude: 114.1583, Latitude: 22.2818",
  "Shenzhen Stock Exchange (SZSE)": "Longitude: 114.0573, Latitude: 22.5264",
  "Euronext (Amsterdam HQ)": "Longitude: 4.8932, Latitude: 52.3740",
  "Deutsche Börse (Frankfurt Stock Exchange)": "Longitude: 8.6782, Latitude: 50.1145",
  "SIX Swiss Exchange (Zurich)": "Longitude: 8.5154, Latitude: 47.3934",
  "B3 (formerly BM&F Bovespa, São Paulo)": "Longitude: -46.6361, Latitude: -23.5475",
  "Bombay Stock Exchange (BSE, Mumbai)": "Longitude: 72.8312, Latitude: 18.9300",
  "National Stock Exchange of India (NSE, Mumbai)": "Longitude: 72.8679, Latitude: 19.0668",
  "Australian Securities Exchange (ASX, Sydney)": "Longitude: 151.2079, Latitude: -33.8640",
  "Toronto Stock Exchange (TSX)": "Longitude: -79.3810, Latitude: 43.6483",
  "Johannesburg Stock Exchange (JSE)": "Longitude: 28.0530, Latitude: -26.1060",
  "Moscow Exchange (MOEX)": "Longitude: 37.6184, Latitude: 55.7557",
  "Korea Exchange (KRX, Busan HQ)": "Longitude: 129.0590, Latitude: 35.1290",
  "Taiwan Stock Exchange (TWSE, Taipei)": "Longitude: 121.5645, Latitude: 25.0336",
  "Bursa Malaysia (Kuala Lumpur)": "Longitude: 101.6865, Latitude: 3.1412",
  "Indonesia Stock Exchange (IDX, Jakarta)": "Longitude: 106.8090, Latitude: -6.2277",
  "Stock Exchange of Thailand (SET, Bangkok)": "Longitude: 100.5680, Latitude: 13.7613",
  "Philippine Stock Exchange (PSE, Manila)": "Longitude: 121.0453, Latitude: 14.5539",
  "Singapore Exchange (SGX)": "Longitude: 103.8500, Latitude: 1.2800",
  "Saudi Stock Exchange (Tadawul, Riyadh)": "Longitude: 46.6753, Latitude: 24.7136",
  "Tel Aviv Stock Exchange (TASE)": "Longitude: 34.7725, Latitude: 32.0623",
  "Warsaw Stock Exchange (GPW)": "Longitude: 21.0262, Latitude: 52.2312",
  "Vienna Stock Exchange (Wiener Börse)": "Longitude: 16.3695, Latitude: 48.2105",
  "Oslo Stock Exchange (Oslo Børs)": "Longitude: 10.7467, Latitude: 59.9080",
  "Nasdaq Nordic (Stockholm Stock Exchange)": "Longitude: 18.0674, Latitude: 59.3289"
}
# Out:
# {'New York Stock Exchange (NYSE)': 'Longitude: -74.0113, Latitude: 40.7069',
#  'NASDAQ (MarketSite in Times Square)': 'Longitude: -73.9855, Latitude: 40.7570',
#  'London Stock Exchange (LSE)': 'Longitude: -0.0983, Latitude: 51.5155',
#  'Tokyo Stock Exchange (TSE)': 'Longitude: 139.7748, Latitude: 35.6828',
#  'Shanghai Stock Exchange (SSE)': 'Longitude: 121.5010, Latitude: 31.2382',
#  'Hong Kong Stock Exchange (HKEX)': 'Longitude: 114.1583, Latitude: 22.2818',
#  'Shenzhen Stock Exchange (SZSE)': 'Longitude: 114.0573, Latitude: 22.5264',
#  'Euronext (Amsterdam HQ)': 'Longitude: 4.8932, Latitude: 52.3740',
#  'Deutsche Börse (Frankfurt Stock Exchange)': 'Longitude: 8.6782, Latitude: 50.1145',
#  'SIX Swiss Exchange (Zurich)': 'Longitude: 8.5154, Latitude: 47.3934',
#  'B3 (formerly BM&F Bovespa, São Paulo)': 'Longitude: -46.6361, Latitude: -23.5475',
#  'Bombay Stock Exchange (BSE, Mumbai)': 'Longitude: 72.8312, Latitude: 18.9300',
#  'National Stock Exchange of India (NSE, Mumbai)': 'Longitude: 72.8679, Latitude: 19.0668',
#  'Australian Securities Exchange (ASX, Sydney)': 'Longitude: 151.2079, Latitude: -33.8640',
#  'Toronto Stock Exchange (TSX)': 'Longitude: -79.3810, Latitude: 43.6483',
#  'Johannesburg Stock Exchange (JSE)': 'Longitude: 28.0530, Latitude: -26.1060',
#  'Moscow Exchange (MOEX)': 'Longitude: 37.6184, Latitude: 55.7557',
#  'Korea Exchange (KRX, Busan HQ)': 'Longitude: 129.0590, Latitude: 35.1290',
#  'Taiwan Stock Exchange (TWSE, Taipei)': 'Longitude: 121.5645, Latitude: 25.0336',
#  'Bursa Malaysia (Kuala Lumpur)': 'Longitude: 101.6865, Latitude: 3.1412',
#  'Indonesia Stock Exchange (IDX, Jakarta)': 'Longitude: 106.8090, Latitude: -6.2277',
#  'Stock Exchange of Thailand (SET, Bangkok)': 'Longitude: 100.5680, Latitude: 13.7613',
#  'Philippine Stock Exchange (PSE, Manila)': 'Longitude: 121.0453, Latitude: 14.5539',
#  'Singapore Exchange (SGX)': 'Longitude: 103.8500, Latitude: 1.2800',
#  'Saudi Stock Exchange (Tadawul, Riyadh)': 'Longitude: 46.6753, Latitude: 24.7136',
#  'Tel Aviv Stock Exchange (TASE)': 'Longitude: 34.7725, Latitude: 32.0623',
#  'Warsaw Stock Exchange (GPW)': 'Longitude: 21.0262, Latitude: 52.2312',
#  'Vienna Stock Exchange (Wiener Börse)': 'Longitude: 16.3695, Latitude: 48.2105',
#  'Oslo Stock Exchange (Oslo Børs)': 'Longitude: 10.7467, Latitude: 59.9080',
#  'Nasdaq Nordic (Stockholm Stock Exchange)': 'Longitude: 18.0674, Latitude: 59.3289'}

# %% [markdown]
# Goal of this Project:
# List all publicly listed securities globally, plot each one to it's respective region then plot on a visual global map.
#
# Grab all listed securities on yahoo Finance, identify where they are globally, assign location, then use widgets app to provide visual overlay.
#
# Practicing:
# - Data Cleaning
# - API usage
# - Data manipulation (i.e., merging)
#
# Market-cap weighted visual of all the data.
# APIs:
# - YFinance by
# - (optional) FRED Data API
# - Widgets (global map)

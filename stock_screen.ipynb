# %%
# %pip install yfinance
# %pip install plotly
# %pip install mplchart
# Out:
# ...
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 3.0/3.0 MB 17.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for peewee: filename=peewee-3.17.9-py3-none-any.whl size=139095 sha256=79bf9c536bb3e4797119268a8255e31e7fae4e2060dbbf40a642f31cc8a8ba55
#   Stored in directory: c:\users\paulp\appdata\local\pip\cache\wheels\a4\4c\13\c0145c208d813977081d42e2a47d72acb3efc4a6965ab57804
# Successfully built peewee
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import plotly.express as px
import yfinance as yf
import plotly.graph_objs as go
import pandas as pd
import numpy as np
import geopy 
import seaborn as sns 
import pycountry
import ipywidgets as widgets
import matplotlib.pyplot as plt
import mplfinance as mp

# %%
# %pip install mplfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from mplchart.chart import Chart
from mplchart.primitives import Candlesticks, Volume
from mplchart.indicators import ROC, SMA, EMA, RSI, MACD

# %%
ticker = "TSLA"
price = yf.Ticker("TSLA").history("5y")
price
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-03-16 00:00:00-04:00   31.299999   32.991333   29.478001   29.671333
# 2020-03-17 00:00:00-04:00   29.334000   31.456667   26.400000   28.680000
# 2020-03-18 00:00:00-04:00   25.933332   26.990667   23.367332   24.081333
# 2020-03-19 00:00:00-04:00   24.980000   30.133333   23.897333   28.509333
# 2020-03-20 00:00:00-04:00   29.213333   31.799999   28.386000   28.502001
# ...                               ...         ...         ...         ...
# 2025-03-10 00:00:00-04:00  252.539993  253.369995  220.000000  222.149994
# 2025-03-11 00:00:00-04:00  225.309998  237.059998  217.020004  230.580002
# 2025-03-12 00:00:00-04:00  247.220001  251.839996  241.100006  248.089996
# 2025-03-13 00:00:00-04:00  248.130005  248.289993  232.600006  240.679993
# 2025-03-14 00:00:00-04:00  247.309998  251.559998  240.740005  251.289993
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
indicators = [Candlesticks(), SMA(50), SMA(200), Volume(), RSI(), MACD(),]
chart = Chart(title="TSLA", max_bars=200)
chart.plot(price, indicators)

# %%
NVDA_prices = yf.Ticker("NVDA").history("5y")
NVDA_prices
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-03-16 00:00:00-04:00    5.290757    5.631751    4.832197    4.891976
# 2020-03-17 00:00:00-04:00    5.004312    5.501232    4.757472    5.411811
# 2020-03-18 00:00:00-04:00    4.984138    5.229235    4.500420    5.051888
# 2020-03-19 00:00:00-04:00    5.030466    5.398361    4.817003    5.304707
# 2020-03-20 00:00:00-04:00    5.454903    5.736864    5.109426    5.124869
# ...                               ...         ...         ...         ...
# 2025-03-10 00:00:00-04:00  109.889891  111.839709  105.450297  106.970161
# 2025-03-11 00:00:00-04:00  106.980159  112.229676  104.760361  108.750000
# 2025-03-12 00:00:00-04:00  114.120003  116.760002  112.879997  115.739998
# 2025-03-13 00:00:00-04:00  117.029999  117.760002  113.790001  115.580002
# 2025-03-14 00:00:00-04:00  118.620003  121.879997  118.150002  120.489998
#
#                               Volume  Dividends  Stock Splits
# Date
# ...
